# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("kiva.csv")

# %%
df
# Out:
#            id  funded_amount  loan_amount                        activity  \
# 0     1236456          425.0        425.0                  Clothing Sales
# 1      959933           75.0         75.0                   Used Clothing
# 2      952357          925.0        925.0                  Clothing Sales
# 3     1153000          175.0        175.0  Primary/secondary school costs
# 4     1142770          200.0        200.0                 Home Appliances
# ...       ...            ...          ...                             ...
# 1413   836933          925.0        925.0                 Home Appliances
# 1414   942053          125.0        125.0                 Home Appliances
# 1415  1209832          775.0        775.0              Education provider
# 1416  1031727           50.0         50.0                   Used Clothing
# 1417  1011545          675.0        675.0       Personal Housing Expenses
#
#             sector                                                use  \
# ...

# %%
df.describe() #some describtion about the dataset
# Out:
#                  id  funded_amount  loan_amount   partner_id  term_in_months  \
# count  1.418000e+03    1418.000000  1418.000000  1397.000000     1418.000000
# mean   1.014517e+06     380.782793   394.834274   202.020759       15.349083
# std    1.985829e+05     242.340434   246.254993   106.392319       10.257455
# min    6.542640e+05       0.000000    25.000000     9.000000        1.000000
# 25%    8.296880e+05     175.000000   200.000000   121.000000        8.000000
# 50%    1.022986e+06     325.000000   350.000000   164.000000       14.000000
# 75%    1.186858e+06     525.000000   568.750000   311.000000       17.000000
# max    1.337798e+06     975.000000   975.000000   466.000000       76.000000
#
#        lender_count
# count   1418.000000
# mean      12.126234
# std        8.240578
# min        0.000000
# 25%        6.000000
# 50%       10.000000
# 75%       18.000000
# max       39.000000

# %%
df.info() #information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1418 entries, 0 to 1417
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1418 non-null   int64
#  1   funded_amount       1418 non-null   float64
#  2   loan_amount         1418 non-null   float64
#  3   activity            1418 non-null   object
#  4   sector              1418 non-null   object
#  5   use                 1418 non-null   object
#  6   country_code        1418 non-null   object
#  7   country             1418 non-null   object
#  8   region              1287 non-null   object
#  9   currency            1418 non-null   object
#  10  partner_id          1397 non-null   float64
#  11  posted_time         1418 non-null   object
#  12  disbursed_time      1418 non-null   object
#  13  funded_time         1357 non-null   object
#  14  term_in_months      1418 non-null   float64
# ...

# %%
df.corr()
# Out:
#                       id  funded_amount  loan_amount  partner_id  \
# id              1.000000      -0.162448    -0.148398    0.213858
# funded_amount  -0.162448       1.000000     0.950472   -0.253612
# loan_amount    -0.148398       0.950472     1.000000   -0.278276
# partner_id      0.213858      -0.253612    -0.278276    1.000000
# term_in_months -0.193331       0.198023     0.207544   -0.004012
# lender_count   -0.179552       0.891363     0.845089   -0.191346
#
#                 term_in_months  lender_count
# id                   -0.193331     -0.179552
# funded_amount         0.198023      0.891363
# loan_amount           0.207544      0.845089
# partner_id           -0.004012     -0.191346
# term_in_months        1.000000      0.206716
# lender_count          0.206716      1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())

# %%
sns.countplot(df['sector'])

# %%
sns.catplot(x = 'sector',
            y = 'loan_amount',data=df,kind = 'boxen')

# %%
sns.catplot(x = 'loan_amount',
            y = 'gender',data=df)
